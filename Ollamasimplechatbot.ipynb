# %%
#Once you've installed Ollama manually, you can download and run LLaMA 3 inside Anaconda Prompt
#ollama --version (Check Ollama Installation)
#ollama pull llama3 ( Download llama3 Model)
#ollama run llama3 (Run llama3 Locally)
#!pip install ollama
import ollama

response = ollama.chat(model="llama3.1",
                       messages=[{"role": "user",
                                  "content": "Give me 3 ideas for apps I could build with OpenAI APIs"}])

print(response['message']['content'])
# Out:
# Here are three potential app ideas you could build using OpenAI APIs:
#
# **Idea 1: AI-Powered Virtual Assistant**
#
# * App Name: Luna
# * Description: Build a virtual assistant app that uses OpenAI's API to respond to user queries, book appointments, set reminders, and more. Luna could integrate with popular services like Google Calendar, Uber, and DoorDash to provide a seamless experience.
# * Features:
# 	+ Natural Language Processing (NLP) to understand user intent and respond accordingly
# 	+ Integration with multiple services to provide a one-stop-shop for user needs
# 	+ Personalized recommendations based on user preferences and behavior
# * Use cases:
# 	+ Virtual event planning assistant
# 	+ Personalized travel planning assistant
# 	+ Customer service chatbot for businesses
#
# **Idea 2: Creative Writing and Storytelling Assistant**
#
# * App Name: StoryCraft
# ...
