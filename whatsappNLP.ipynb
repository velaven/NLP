# %%
import pandas as pd

# %%
df = pd.read_csv("WhatsApp Chat with VASTHUPARAM.txt",header=None,on_bad_lines='skip',encoding='utf8')

# %%
df
# Out:
#             0                                                  1           2  \
# 0    24/11/25   7:24 pm - Messages and calls are end-to-end e...   listen to
# 1    24/11/25   7:24 pm - Vasthuparam created group "VASTHUPA...         NaN
# 2    24/11/25                    7:24 pm - Vasthuparam added you         NaN
# 3    24/11/25            7:25 pm - Vasthuparam added Kalaiarasan         NaN
# 4    24/11/25   7:25 pm - Vasthuparam turned on admin approva...         NaN
# ..        ...                                                ...         ...
# 563  06/02/26                           2:10 pm - Kavithajio: Hi         NaN
# 564  06/02/26             2:12 pm - Vasthuparam: <Media omitted>         NaN
# 565  06/02/26             2:12 pm - Vasthuparam: <Media omitted>         NaN
# 566  06/02/26   2:14 pm - Kavithajio: Ok.. small change as di...         NaN
# 567  06/02/26             4:51 pm - Vasthuparam: <Media omitted>         NaN
#
#                                3
# 0     or share them. Learn more.
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 563                          NaN
# 564                          NaN
# 565                          NaN
# 566                          NaN
# 567                          NaN
#
# [568 rows x 4 columns]

# %%
df=df.drop(index=0)

# %%
df=df.drop(columns=[2,3])

# %%
df.columns=['Date','chat']

# %%
df
# Out:
#          Date                                               chat
# 1    24/11/25   7:24 pm - Vasthuparam created group "VASTHUPA...
# 2    24/11/25                    7:24 pm - Vasthuparam added you
# 3    24/11/25            7:25 pm - Vasthuparam added Kalaiarasan
# 4    24/11/25   7:25 pm - Vasthuparam turned on admin approva...
# 5    24/11/25   7:25 pm - Vasthuparam turned off admin approv...
# ..        ...                                                ...
# 563  06/02/26                           2:10 pm - Kavithajio: Hi
# 564  06/02/26             2:12 pm - Vasthuparam: <Media omitted>
# 565  06/02/26             2:12 pm - Vasthuparam: <Media omitted>
# 566  06/02/26   2:14 pm - Kavithajio: Ok.. small change as di...
# 567  06/02/26             4:51 pm - Vasthuparam: <Media omitted>
#
# [567 rows x 2 columns]

# %%
message=df["chat"].str.split("-",n=1,expand=True)

# %%
message
# Out:
#              0                                                  1
# 1     7:24 pm             Vasthuparam created group "VASTHUPARAM"
# 2     7:24 pm                               Vasthuparam added you
# 3     7:25 pm                       Vasthuparam added Kalaiarasan
# 4     7:25 pm    Vasthuparam turned on admin approval to join ...
# 5     7:25 pm    Vasthuparam turned off admin approval to join...
# ..         ...                                                ...
# 563   2:10 pm                                      Kavithajio: Hi
# 564   2:12 pm                        Vasthuparam: <Media omitted>
# 565   2:12 pm                        Vasthuparam: <Media omitted>
# 566   2:14 pm          Kavithajio: Ok.. small change as discussed
# 567   4:51 pm                        Vasthuparam: <Media omitted>
#
# [567 rows x 2 columns]

# %%
df["Time"]=message[0]

# %%
message1=message[1].str.split(":",n=1,expand=True)

# %%
message1
# Out:
#                                                      0  \
# 1              Vasthuparam created group "VASTHUPARAM"
# 2                                Vasthuparam added you
# 3                        Vasthuparam added Kalaiarasan
# 4     Vasthuparam turned on admin approval to join ...
# 5     Vasthuparam turned off admin approval to join...
# ..                                                 ...
# 563                                         Kavithajio
# 564                                        Vasthuparam
# 565                                        Vasthuparam
# 566                                         Kavithajio
# 567                                        Vasthuparam
#
#                                    1
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# 5                               None
# ..                               ...
# 563                               Hi
# 564                  <Media omitted>
# 565                  <Media omitted>
# 566   Ok.. small change as discussed
# 567                  <Media omitted>
#
# [567 rows x 2 columns]

# %%
df["Name"]=message1[0]

# %%
df["chat"]=message1[1]

# %%
df=df[["Date","Time","Name","chat"]]

# %%
df
# Out:
#          Date       Time                                               Name  \
# 1    24/11/25   7:24 pm             Vasthuparam created group "VASTHUPARAM"
# 2    24/11/25   7:24 pm                               Vasthuparam added you
# 3    24/11/25   7:25 pm                       Vasthuparam added Kalaiarasan
# 4    24/11/25   7:25 pm    Vasthuparam turned on admin approval to join ...
# 5    24/11/25   7:25 pm    Vasthuparam turned off admin approval to join...
# ..        ...        ...                                                ...
# 563  06/02/26   2:10 pm                                          Kavithajio
# 564  06/02/26   2:12 pm                                         Vasthuparam
# 565  06/02/26   2:12 pm                                         Vasthuparam
# 566  06/02/26   2:14 pm                                          Kavithajio
# 567  06/02/26   4:51 pm                                         Vasthuparam
#
#                                 chat
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# 5                               None
# ..                               ...
# 563                               Hi
# 564                  <Media omitted>
# 565                  <Media omitted>
# 566   Ok.. small change as discussed
# 567                  <Media omitted>
#
# [567 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 1 to 567
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    567 non-null    object
#  1   Time    183 non-null    object
#  2   Name    183 non-null    object
#  3   chat    173 non-null    object
# dtypes: object(4)
# memory usage: 17.8+ KB

# %%
#!pip install --upgrade pip

# %%
#%pip install --upgrade pip

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (3.9.2)
# Requirement already satisfied: click in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (3.3.2)
# Requirement already satisfied: requests in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from vaderSentiment) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from requests->vaderSentiment) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from requests->vaderSentiment) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from requests->vaderSentiment) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages (from requests->vaderSentiment) (2026.1.4)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyser
import nltk
nltk.download('vader_lexion')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from nltk.sentiment.vader import SentimentIntensityAnalyser
#       2 import nltk
#       3 nltk.download('vader_lexion')
#
# ImportError: cannot import name 'SentimentIntensityAnalyser' from 'nltk.sentiment.vader' (C:\Users\KAVITHA\anaconda3\envs\ainlp\Lib\site-packages\nltk\sentiment\vader.py)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyser
sia = SentimentIntensityAnalyser()
text = 'ok'
scores = sia.polarity_scores(text))
print(scores)
