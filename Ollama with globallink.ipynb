# %%
#!pip install gradio

# %%
import ollama
import gradio as gr         
# System message (for context)
system_msg = "You are a financial expert specializing in real estate investment and negotiation."

# Chatbot function
def CustomLlama3_1(user_input):
    # Format the conversation context
    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": user_input}
    ]

    # Generate response using Ollama's Llama 3 model
    response = ollama.chat(model="llama3_1", messages=messages)

    # Extract and return response text
    return response['message']['content']

# Gradio Interface
demo = gr.Interface(fn=CustomLlama3_1, 
                    inputs="text", 
                    outputs="text", 
                    title="My Saving Assistant")

# Launch the app
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\blocks.py", line 2157, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\blocks.py", line 1634, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         fn, *processed_input, limiter=self.limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\utils.py", line 1038, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\KAVITHA\AppData\Local\Temp\ipykernel_17444\2888211358.py", line 15, in CustomLlama3_1
#     response = ollama.chat(model="llama3_1", messages=messages)
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\ollama\_client.py", line 365, in chat
#     return self._request(
#            ~~~~~~~~~~~~~^
#       ChatResponse,
#       ^^^^^^^^^^^^^
#     ...<14 lines>...
#       stream=stream,
#       ^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\ollama\_client.py", line 189, in _request
#     return cls(**self._request_raw(*args, **kwargs).json())
#                  ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\ollama\_client.py", line 133, in _request_raw
#     raise ResponseError(e.response.text, e.response.status_code) from None
# ollama._types.ResponseError: model 'llama3_1' not found (status code: 404)
# Traceback (most recent call last):
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\blocks.py", line 2157, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\blocks.py", line 1634, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         fn, *processed_input, limiter=self.limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\gradio\utils.py", line 1038, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\KAVITHA\AppData\Local\Temp\ipykernel_17444\2888211358.py", line 15, in CustomLlama3_1
#     response = ollama.chat(model="llama3_1", messages=messages)
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\ollama\_client.py", line 365, in chat
#     return self._request(
#            ~~~~~~~~~~~~~^
#       ChatResponse,
#       ^^^^^^^^^^^^^
#     ...<14 lines>...
#       stream=stream,
#       ^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\ollama\_client.py", line 189, in _request
#     return cls(**self._request_raw(*args, **kwargs).json())
#                  ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\KAVITHA\anaconda3\Lib\site-packages\ollama\_client.py", line 133, in _request_raw
#     raise ResponseError(e.response.text, e.response.status_code) from None
# ollama._types.ResponseError: model 'llama3_1' not found (status code: 404)
