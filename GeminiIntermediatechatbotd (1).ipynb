# %%
#!pip install pandas
#!pip install -U google-generativeai as genai
import pandas as pd
import os
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyBkcViMgJYN09JfFUyLL5BAC6WSjOCj0N8") # Replace with your actual Gemini API key

# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready!")

# Load the model
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = model.generate_content(user_input)

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  you are a chef
# Your new assistant is ready!
#  how to cook veg biriyani
# Cooking an authentic Vegetable Biryani is all about the balance of aromatics, long-grain basmati rice, and perfectly cooked vegetables. The best method is the **"Dum" style**, where the rice and vegetables are layered and slow-cooked together.
#
# Here is a step-by-step guide to making a restaurant-style Veg Biryani.
#
# ### 1. Ingredients
#
# **For the Rice:**
# *   2 cups Long-grain Basmati Rice (soaked for 30 mins)
# *   Whole spices: 1 bay leaf, 3 green cardamoms, 1-inch cinnamon stick, 3 cloves
# *   Salt (plenty, like sea water)
# *   1 tsp Oil or Ghee
#
# **For the Vegetable Masala:**
# *   2 cups mixed chopped vegetables (Carrots, Beans, Cauliflower, Peas, Potatoes)
# *   1 cup thick Yogurt (curd)
# *   2 large Onions (thinly sliced)
# *   1 tbsp Ginger-Garlic paste
# *   2-3 Green chilies (slit)
# *   Spices: 1 tsp Red chili powder, ½ tsp Turmeric, 1 tbsp Biryani Masala powder
# *   Handful of Fresh Mint and Coriander leaves
#
# **For Layering & Garnish:**
# *   A pinch of Saffron soaked in 2 tbsp warm milk (or yellow food color)
# *   2 tbsp Ghee
# *   Fried onions (Birista)
#
# ---
#
# ### 2. Instructions
#
# #### Step 1: Prepare the Fried Onions (Birista)
# In a pan, deep-fry or shallow-fry half of your sliced onions in oil/ghee until they are golden brown and crispy. Drain on a paper towel. These add the signature "smoky" sweetness to biryani.
#
# #### Step 2: Par-boil the Rice
# 1.  Boil a large pot of water. Add the whole spices (bay leaf, cardamom, etc.), salt, and 1 tsp oil.
# 2.  Add the soaked rice.
# 3.  **Crucial:** Cook until the rice is only **70-80% done** (it should still have a slight "bite" or core).
# 4.  Drain the water completely and spread the rice on a plate to prevent overcooking.
#
# #### Step 3: Cook the Vegetable Masala
# 1.  Heat 2 tbsp oil/ghee in a heavy-bottomed pot (or pressure cooker used as a pot).
# 2.  Add the remaining raw onions and sauté until golden. Add ginger-garlic paste and green chilies; sauté for a minute.
# 3.  Add all the vegetables and sauté for 3-4 minutes.
# 4.  Lower the heat. Add the yogurt, red chili powder, turmeric, and biryani masala. Mix well.
# 5.  Cover and cook for 5-7 minutes until the vegetables are 80% cooked. (Don't add too much water; the gravy should be thick).
#
# #### Step 4: The Layering (The "Dum")
# 1.  If your pot is small, take out half the vegetables. Otherwise, just level the vegetables at the bottom of the pot.
# 2.  Spread half of the par-boiled rice over the vegetables.
# 3.  Sprinkle some fried onions, chopped mint, and coriander.
# 4.  Add the remaining rice as the top layer.
# 5.  Drizzle the saffron milk and ghee over the top. Sprinkle the rest of the fried onions and mint/coriander.
#
# #### Step 5: The Slow Cook (Dum)
# 1.  Seal the pot with a tight-fitting lid. You can use aluminum foil or a clean cloth under the lid to trap the steam.
# 2.  Place the pot on the lowest flame possible.
# 3.  **Pro Tip:** If your pot has a thin bottom, place it on a flat tawa (griddle) to prevent the bottom from burning.
# 4.  Let it steam for **15–20 minutes**.
# 5.  Turn off the heat and let it rest for another 10 minutes before opening.
#
# ---
#
# ### 3. Tips for Success
# *   **The Rice:** Always use high-quality, aged Basmati rice. Do not stir the rice while it's boiling, or the grains will break.
# *   **The Salt:** The water for boiling rice should be salty. Most of it drains away, but this is the only chance to season the rice grains themselves.
# *   **Paneer:** If you like Paneer, lightly fry cubes and add them to the vegetable masala at the very end.
#
# **Serve with:** Cool Cucumber Raita (yogurt dip), Salan (spicy gravy), or a simple onion salad.
